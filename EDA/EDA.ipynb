# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# %%
df = pd.read_csv("../Dataset/rice_cleaned.csv")
df.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)  Per Capita GNI  Per Capita GDP  \
# 0  2004                                  198           43841           46664
# 1  2005                                  233           47046           49867
# 2  2006                                  250           52201           53655
# 3  2007                                  274           57866           59429
# 4  2008                                  246           54524           56607
#
#    Per Capita GNI (US Dollar)  Per Capita GDP (US Dollar)  \
# 0                       25937                       27607
# 1                       28263                       29957
# 2                       32854                       33769
# 3                       38396                       39433
# 4                       38538                       40011
#
#    Inflation, consumer prices (annual %)  Mean_Price_USD_per_Metric_Ton  \
# 0                               1.662727                         250.78
# ...

# %%
print(list(df.columns))
# Out:
# ['Year', 'Rice Domestic Consumption (1000 MT)', 'Per Capita GNI', 'Per Capita GDP', 'Per Capita GNI (US Dollar)', 'Per Capita GDP (US Dollar)', 'Inflation, consumer prices (annual %)', 'Mean_Price_USD_per_Metric_Ton', 'Total Population (Number)', 'Resident Population (Number)', 'Singapore Citizen Population (Number)', 'Permanent Resident Population (Number)', 'Non-Resident Population (Number)', 'Total Population Growth (Per Cent)', 'Resident Population Growth (Per Cent)', 'Population Density (Total Population Per Square Kilometre)', 'Sex Ratio (Males Per Thousand Females)', 'Median Age Of Resident Population (Years)', 'Median Age Of Citizen Population (Years)', 'Old-Age Support Ratio: Residents Aged 15-64 Years Per Resident Aged 65 Years & Over (Number)', 'Age Dependency Ratio: Residents Aged Under 15 Years And 65 Years Per Hundred Residents Aged 15-64 Years (Number)', 'Child Dependency Ratio: Residents Aged Under 15 Years Per Hundred Residents Aged 15-64 Years (Number)', 'Old-Age De
# ...
