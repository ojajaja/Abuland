# %% [markdown]
# # Data Cleaning

# %%
# Import Statements
import pandas as pd

# %% [markdown]
# ### "Rice Domestic Consumption" Data Cleaning

# %%
dc = pd.read_csv("../Dataset/domestic_consumption.csv")
dc.head()
# Out:
#    Market Year  Domestic Consumption Unit of Measure Growth Rate
# 0         1960                   192       (1000 MT)         NaN
# 1         1961                   192       (1000 MT)       0.00%
# 2         1962                   162       (1000 MT)     -15.63%
# 3         1963                   217       (1000 MT)      33.95%
# 4         1964                   161       (1000 MT)     -25.81%

# %%
dc1 = dc[dc['Market Year']>=2004]
dc1.reset_index(inplace=True, drop=True)
dc2 = dc1.drop(columns=['Unit of Measure', 'Growth Rate'])
dc2.head()
# Out:
#    Market Year  Domestic Consumption
# 0         2004                   198
# 1         2005                   233
# 2         2006                   250
# 3         2007                   274
# 4         2008                   246

# %%
dc2.rename(columns={'Market Year': 'Year', 'Domestic Consumption': 'Rice Domestic Consumption (1000 MT)'}, inplace=True)
dc2.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)
# 0  2004                                  198
# 1  2005                                  233
# 2  2006                                  250
# 3  2007                                  274
# 4  2008                                  246

# %%
dc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Year                                 20 non-null     int64
#  1   Rice Domestic Consumption (1000 MT)  20 non-null     int64
# dtypes: int64(2)
# memory usage: 448.0 bytes

# %% [markdown]
# ### "Singapore Population" Data Cleaning

# %%
sp = pd.read_csv("../Dataset/sing_population.csv")
sp.head()
# Out:
#      Country  Year Total Population (Number) Resident Population (Number)  \
# 0  Sinagpore  2023                 5,917,648                    4,149,253
# 1  Sinagpore  2022                 5,637,022                    4,073,239
# 2  Sinagpore  2021                 5,453,566                    3,986,842
# 3  Sinagpore  2020                 5,685,807                    4,044,210
# 4  Sinagpore  2019                 5,703,569                    4,026,209
#
#   Singapore Citizen Population (Number)  \
# 0                             3,610,658
# 1                             3,553,749
# 2                             3,498,191
# 3                             3,523,191
# 4                             3,500,940
#
#   Permanent Resident Population (Number) Non-Resident Population (Number)  \
# 0                                538,595                        1,768,395
# 1                                519,490                        1,563,783
# ...

# %%
len(sp)
# Out:
# 24

# %%
sp1 = sp[sp['Year']>=2004]
sp1.reset_index(inplace=True, drop=True)
sp1.head()
# Out:
#      Country  Year Total Population (Number) Resident Population (Number)  \
# 0  Sinagpore  2023                 5,917,648                    4,149,253
# 1  Sinagpore  2022                 5,637,022                    4,073,239
# 2  Sinagpore  2021                 5,453,566                    3,986,842
# 3  Sinagpore  2020                 5,685,807                    4,044,210
# 4  Sinagpore  2019                 5,703,569                    4,026,209
#
#   Singapore Citizen Population (Number)  \
# 0                             3,610,658
# 1                             3,553,749
# 2                             3,498,191
# 3                             3,523,191
# 4                             3,500,940
#
#   Permanent Resident Population (Number) Non-Resident Population (Number)  \
# 0                                538,595                        1,768,395
# 1                                519,490                        1,563,783
# ...

# %%
len(sp1)
# Out:
# 20

# %%
sp1 = sp.drop(columns=['Country'])
sp1.head()
# Out:
#    Year Total Population (Number) Resident Population (Number)  \
# 0  2023                 5,917,648                    4,149,253
# 1  2022                 5,637,022                    4,073,239
# 2  2021                 5,453,566                    3,986,842
# 3  2020                 5,685,807                    4,044,210
# 4  2019                 5,703,569                    4,026,209
#
#   Singapore Citizen Population (Number)  \
# 0                             3,610,658
# 1                             3,553,749
# 2                             3,498,191
# 3                             3,523,191
# 4                             3,500,940
#
#   Permanent Resident Population (Number) Non-Resident Population (Number)  \
# 0                                538,595                        1,768,395
# 1                                519,490                        1,563,783
# 2                                488,651                        1,466,724
# ...

# %%
sp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 30 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Year                                                                                                                     24 non-null     int64
#  1   Total Population (Number)                                                                                                24 non-null     object
#  2   Resident Population (Number)                                                                                             24 non-null     object
# ...

# %% [markdown]
# ### "Rice Price" Data Cleaning

# %%
rp = pd.read_csv("../Dataset/rice_price.csv")
rp.head()
# Out:
#    Year  Mean_Price_USD_per_Metric_Ton
# 0  2004                         250.78
# 1  2005                         287.08
# 2  2006                         310.95
# 3  2007                         319.55
# 4  2008                         577.13

# %%
rp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           20 non-null     int64
#  1   Mean_Price_USD_per_Metric_Ton  20 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 448.0 bytes

# %% [markdown]
# ### "Sinagpore GDP" Data Cleaning

# %%
gdp = pd.read_csv("../Dataset/sing_gdp.csv")
gdp.head()
# Out:
#    DataSeries  Per Capita GNI  Per Capita GDP  Per Capita GNI (US Dollar)  \
# 0        2023           95455          113779                       71071
# 1        2022           98550          121914                       71470
# 2        2021           90948          106942                       67670
# 3        2020           73243           84808                       53105
# 4        2019           79698           90145                       58421
#
#    Per Capita GDP (US Dollar)
# 0                       84714
# 1                       88414
# 2                       79570
# 3                       61491
# 4                       66079

# %%
gdp1 = gdp[gdp['DataSeries']>=2004]
gdp1.reset_index(inplace=True, drop=True)
gdp2 = gdp1.rename(columns={"DataSeries":"Year"})
gdp2.head()
# Out:
#    Year  Per Capita GNI  Per Capita GDP  Per Capita GNI (US Dollar)  \
# 0  2023           95455          113779                       71071
# 1  2022           98550          121914                       71470
# 2  2021           90948          106942                       67670
# 3  2020           73243           84808                       53105
# 4  2019           79698           90145                       58421
#
#    Per Capita GDP (US Dollar)
# 0                       84714
# 1                       88414
# 2                       79570
# 3                       61491
# 4                       66079

# %%
print(len(gdp2))
print(len(gdp))
# Out:
# 20
# 64

# %%
gdp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        20 non-null     int64
#  1   Per Capita GNI              20 non-null     int64
#  2   Per Capita GDP              20 non-null     int64
#  3   Per Capita GNI (US Dollar)  20 non-null     int64
#  4   Per Capita GDP (US Dollar)  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %% [markdown]
# ### "Singapore Inflation" Data Cleaning

# %%
si = pd.read_csv("../Dataset/sing_inflation.csv")
si.head()
# Out:
#    Inflation, consumer prices (annual %)  Country Name
# 0                               1.662727          2004
# 1                               0.425106          2005
# 2                               0.962902          2006
# 3                               2.104880          2007
# 4                               6.627782          2008

# %%
si1 = si.rename(columns={"Country Name": "Year"})
si1.head()
# Out:
#    Inflation, consumer prices (annual %)  Year
# 0                               1.662727  2004
# 1                               0.425106  2005
# 2                               0.962902  2006
# 3                               2.104880  2007
# 4                               6.627782  2008

# %% [markdown]
# ### "India Precipitation" Data Cleaning

# %%
ip = pd.read_csv("../Dataset/india_rainfall.csv")
ip.head()
# Out:
#    Year  Precipitation(mm)
# 0  2004            1030.22
# 1  2005            1116.76
# 2  2006            1190.39
# 3  2007            1136.20
# 4  2008            1157.89

# %%
ip1 = ip.rename(columns={"Precipitation(mm)":"India_Precipitation(mm)"})
ip1.head()
# Out:
#    Year  India_Precipitation(mm)
# 0  2004                  1030.22
# 1  2005                  1116.76
# 2  2006                  1190.39
# 3  2007                  1136.20
# 4  2008                  1157.89

# %%
ip1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     19 non-null     int64
#  1   India_Precipitation(mm)  19 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 432.0 bytes

# %% [markdown]
# ### "India Surface Temperature" Data Cleaning

# %%
ist = pd.read_csv("../Dataset/india_temp.csv")
ist.head()
# Out:
#    Category  Annual Mean  5-yr smooth
# 0      1901        24.39        24.50
# 1      1902        24.64        24.37
# 2      1903        24.08        24.25
# 3      1904        24.12        24.15
# 4      1905        23.99        24.08

# %%
ist1 = ist.drop(columns=['5-yr smooth'])
ist2 = ist1[ist1["Category"]>=2004]
ist3 = ist2.rename(columns={"Category":"Year", "Annual Mean":"India_Temp(°C)"})
ist3.head()
# Out:
#      Year  India_Temp(°C)
# 103  2004           25.04
# 104  2005           24.81
# 105  2006           25.11
# 106  2007           25.13
# 107  2008           24.87

# %%
ist1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     122 non-null    int64
#  1   Annual Mean  122 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.0 KB

# %% [markdown]
# ### "Thailand Precipitaion" Data Cleaning

# %%
tp = pd.read_csv("../Dataset/thai_rainfall.csv")
tp.head()
# Out:
#    Category  Annual Mean  5-yr smooth
# 0      1901      1597.72      1532.40
# 1      1902      1509.18      1549.99
# 2      1903      1531.85      1566.54
# 3      1904      1569.10      1581.08
# 4      1905      1615.15      1592.48

# %%
tp1 = tp.drop(columns=['5-yr smooth'])
tp2 = tp1[tp1["Category"]>=2004]
tp3 = tp2.rename(columns={"Category":"Year", "Annual Mean":"Thailand_Precipitation(mm)"})
tp3.head()
# Out:
#      Year  Thailand_Precipitation(mm)
# 103  2004                     1438.80
# 104  2005                     1581.45
# 105  2006                     1714.52
# 106  2007                     1662.52
# 107  2008                     1712.79

# %% [markdown]
# ### "Thailand Surface Temperature" Data Cleaning

# %%
tst = pd.read_csv("../Dataset/thai_temp.csv")
tst.head()
# Out:
#    Category  Annual Mean  5-yr smooth
# 0      1901        26.59        26.44
# 1      1902        26.52        26.48
# 2      1903        26.19        26.51
# 3      1904        26.04        26.54
# 4      1905        27.10        26.55

# %%
tst1 = tst.drop(columns=['5-yr smooth'])
tst2 = tst1[tst1["Category"]>=2004]
tst3 = tst2.rename(columns={"Category":"Year", "Annual Mean":"Thailand_Temp(°C)"})
tst3.head()
# Out:
#      Year  Thailand_Temp(°C)
# 103  2004              26.64
# 104  2005              26.85
# 105  2006              26.74
# 106  2007              26.64
# 107  2008              26.29

# %% [markdown]
# ### Merge Datasets

# %%
## India Merge
merge1 = ip1.merge(ist3, left_on="Year", right_on="Year")
merge1.head()
# Out:
#    Year  India_Precipitation(mm)  India_Temp(°C)
# 0  2004                  1030.22           25.04
# 1  2005                  1116.76           24.81
# 2  2006                  1190.39           25.11
# 3  2007                  1136.20           25.13
# 4  2008                  1157.89           24.87

# %%
## Thailand Merge
merge2 = tp3.merge(tst3, left_on="Year", right_on="Year")
merge2.head()
# Out:
#    Year  Thailand_Precipitation(mm)  Thailand_Temp(°C)
# 0  2004                     1438.80              26.64
# 1  2005                     1581.45              26.85
# 2  2006                     1714.52              26.74
# 3  2007                     1662.52              26.64
# 4  2008                     1712.79              26.29

# %%
## Singapore Merge
merge3 = dc2.merge(gdp2, left_on="Year", right_on="Year")
merge3.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)  Per Capita GNI  Per Capita GDP  \
# 0  2004                                  198           43841           46664
# 1  2005                                  233           47046           49867
# 2  2006                                  250           52201           53655
# 3  2007                                  274           57866           59429
# 4  2008                                  246           54524           56607
#
#    Per Capita GNI (US Dollar)  Per Capita GDP (US Dollar)
# 0                       25937                       27607
# 1                       28263                       29957
# 2                       32854                       33769
# 3                       38396                       39433
# 4                       38538                       40011

# %%
merge4 = si1.merge(rp, left_on="Year", right_on="Year")
merge4.head()
# Out:
#    Inflation, consumer prices (annual %)  Year  Mean_Price_USD_per_Metric_Ton
# 0                               1.662727  2004                         250.78
# 1                               0.425106  2005                         287.08
# 2                               0.962902  2006                         310.95
# 3                               2.104880  2007                         319.55
# 4                               6.627782  2008                         577.13

# %%
merge5 = merge3.merge(merge4, left_on="Year", right_on="Year")
merge5.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)  Per Capita GNI  Per Capita GDP  \
# 0  2004                                  198           43841           46664
# 1  2005                                  233           47046           49867
# 2  2006                                  250           52201           53655
# 3  2007                                  274           57866           59429
# 4  2008                                  246           54524           56607
#
#    Per Capita GNI (US Dollar)  Per Capita GDP (US Dollar)  \
# 0                       25937                       27607
# 1                       28263                       29957
# 2                       32854                       33769
# 3                       38396                       39433
# 4                       38538                       40011
#
#    Inflation, consumer prices (annual %)  Mean_Price_USD_per_Metric_Ton
# 0                               1.662727                         250.78
# ...

# %%
merge6 = merge5.merge(sp1, left_on="Year", right_on="Year")
merge6.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)  Per Capita GNI  Per Capita GDP  \
# 0  2004                                  198           43841           46664
# 1  2005                                  233           47046           49867
# 2  2006                                  250           52201           53655
# 3  2007                                  274           57866           59429
# 4  2008                                  246           54524           56607
#
#    Per Capita GNI (US Dollar)  Per Capita GDP (US Dollar)  \
# 0                       25937                       27607
# 1                       28263                       29957
# 2                       32854                       33769
# 3                       38396                       39433
# 4                       38538                       40011
#
#    Inflation, consumer prices (annual %)  Mean_Price_USD_per_Metric_Ton  \
# 0                               1.662727                         250.78
# ...

# %%
## Thailand & India Merge
merge7 = merge1.merge(merge2, left_on="Year", right_on="Year")
merge7.head()
# Out:
#    Year  India_Precipitation(mm)  India_Temp(°C)  Thailand_Precipitation(mm)  \
# 0  2004                  1030.22           25.04                     1438.80
# 1  2005                  1116.76           24.81                     1581.45
# 2  2006                  1190.39           25.11                     1714.52
# 3  2007                  1136.20           25.13                     1662.52
# 4  2008                  1157.89           24.87                     1712.79
#
#    Thailand_Temp(°C)
# 0              26.64
# 1              26.85
# 2              26.74
# 3              26.64
# 4              26.29

# %%
## Final Merge
final_merge = merge6.merge(merge7, right_on="Year", left_on="Year")
final_merge.head()
# Out:
#    Year  Rice Domestic Consumption (1000 MT)  Per Capita GNI  Per Capita GDP  \
# 0  2004                                  198           43841           46664
# 1  2005                                  233           47046           49867
# 2  2006                                  250           52201           53655
# 3  2007                                  274           57866           59429
# 4  2008                                  246           54524           56607
#
#    Per Capita GNI (US Dollar)  Per Capita GDP (US Dollar)  \
# 0                       25937                       27607
# 1                       28263                       29957
# 2                       32854                       33769
# 3                       38396                       39433
# 4                       38538                       40011
#
#    Inflation, consumer prices (annual %)  Mean_Price_USD_per_Metric_Ton  \
# 0                               1.662727                         250.78
# ...

# %%
final_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 41 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Year                                                                                                                     19 non-null     int64
#  1   Rice Domestic Consumption (1000 MT)                                                                                      19 non-null     int64
#  2   Per Capita GNI                                                                                                           19 non-null     int64
# ...

# %% [markdown]
# ### Write to CSV

# %%
## write to csv
final_merge.to_csv('../Dataset/rice_cleaned.csv', index=False)
